# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("final_table.csv")

# %%
data.head()
# Out:
#   transaction_date  online_order order_status           brand product_line  \
# 0       2017-02-25           0.0     Approved           Solex     Standard
# 1       2017-10-16           0.0     Approved  Giant Bicycles     Standard
# 2       2017-04-26           0.0     Approved           Solex     Standard
# 3       2017-05-21           1.0     Approved   Trek Bicycles     Standard
# 4       2017-10-05           0.0     Approved  Giant Bicycles     Standard
#
#   product_class product_size  list_price  standard_cost  \
# 0        medium       medium       71.49          53.62
# 1        medium       medium     1403.50         954.82
# 2        medium       medium      478.16         298.72
# 3        medium        large     2091.47         388.92
# 4          high       medium     1129.13         677.48
#
#    product_first_sold_date  ... wealth_segment  deceased_indicator owns_car  \
# 0                  41245.0  ...  Mass Customer                   N      Yes
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19114 entries, 0 to 19113
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_date                     19114 non-null  object
#  1   online_order                         19114 non-null  float64
#  2   order_status                         19114 non-null  object
#  3   brand                                19114 non-null  object
#  4   product_line                         19114 non-null  object
#  5   product_class                        19114 non-null  object
#  6   product_size                         19114 non-null  object
#  7   list_price                           19114 non-null  float64
#  8   standard_cost                        19114 non-null  float64
#  9   product_first_sold_date              19114 non-null  float64
#  10  gender                               19114 non-null  object
# ...

# %%
data.dtypes
# Out:
# transaction_date                        object
# online_order                           float64
# order_status                            object
# brand                                   object
# product_line                            object
# product_class                           object
# product_size                            object
# list_price                             float64
# standard_cost                          float64
# product_first_sold_date                float64
# gender                                  object
# past_3_years_bike_related_purchases      int64
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                 float64
# address                                 object
# postcode                                 int64
# ...

# %%
plt.figure(figsize=(6,5),dpi=75)
plt.hist(data["brand"],bins=15)
plt.xticks(rotation=45)
plt.show()

# %%
data.brand.value_counts(normalize=True).plot.pie()
plt.show()

# %% [markdown]
# Solex is the most famous brand from above all

# %%
data.job_industry_category.value_counts(normalize=True).plot.pie()
plt.show()

# %%
data.job_industry_category.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# Manufacturing is at the top of the list

# %%
corr=data.corr()
sns.heatmap(corr,annot=True)

# %%
sns.countplot(data["gender"])
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# There are slightly more women than men in this data set.

# %%
sns.countplot(data["online_order"])
plt.show()

# %% [markdown]
# There are equal number of people using online and offline mode

# %%
plt.hist(data["Age"],bins=50)
plt.title("Distribution of Age")
plt.xlabel("AGE")
plt.show()

# %% [markdown]
# There are lots of customer whose age are between 40 to 50

# %%
plt.hist(x="Age",data=data[data["gender"] == "Male"],label="MALE",alpha=0.5)
plt.hist(x="Age",data=data[data["gender"] == "Female"],label="FEMALE",alpha=0.5)
plt.title('Distribution of Age by gender')
plt.xlabel('Age')
plt.legend()
plt.show()

# %% [markdown]
# There are a Men aged between 40 to 50 more than women aged between 40 to 50.
